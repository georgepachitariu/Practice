# %%
# https://matplotlib.org/stable/tutorials/introductory/usage.html#

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots()
ax.plot([0,1,3,4], [-1,7,-2,-10])

# %%
fig = plt.figure()
#fig, ax = plt.subplots()
fig, axs = plt.subplots(2, 2)

# %%
import numpy as np

# %%
np.random.seed(1)
data = {
    'a': np.arange(50),
    'c': np.random.randint(0, 50, 50),
    'd': np.random.randn(50) * 100
}

fig, ax = plt.subplots()
ax.scatter('a', 'c', s='d', data=data)

# %%
def my_plotter(ax, data1, data2, param_dict):
    out = ax.plot(data1, data2, **param_dict)
    return out

data1, data2, data3, data4 = np.random.randn(4, 100)
fix, (ax1, ax2) = plt.subplots(1,2)
my_plotter(ax1, data1, data2, {'marker': 'x'})
my_plotter(ax2, data2, data3, {'marker': 'o'})

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.plot(data1, 'o', label='data1')
ax.legend();

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.plot(data1, label='data1')
ax.annotate('interesting point', xy=(30,-1),
            arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# Text(30, -1, 'interesting point')

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.bar(["a", "b", "c"], [-1,3,2])
# Out:
# <BarContainer object of 3 artists>

# %%
fig, axd = plt.subplot_mosaic([['upleft', 'right'],
                               ['lowleft', 'right']], layout='constrained')
axd['upleft'].set_title('upleft')
axd['lowleft'].set_title('lowleft')
axd['right'].set_title('right');
